# %%
import pandas as pd
import matplotlib.pyplot as plt
import lasio

# %%
las = lasio.read(r"15_9-F-1B.LAS")

# %%
las.sections.keys()
# Out:
# dict_keys(['Version', 'Well', 'Curves', 'Parameter', 'Other'])

# %%
las.sections['Version']
# Out:
# [HeaderItem(mnemonic="VERS", unit="", value="2.0", descr="CWLS log ASCII Standa"),
#  HeaderItem(mnemonic="WRAP", unit="", value="NO", descr="One line per depth ste")]

# %%
for item in las.sections['Well']:
    print(f"{item.descr} \t ({item.mnemonic}): \t\t {item.value}")
# Out:
# START 	 (STRT): 		 145.9
# STOP 	 (STOP): 		 3464.9
# STEP 	 (STEP): 		 0.1
# NULL VALUE 	 (NULL): 		 -999.25
# Company 	 (COMP): 		 Statoil Petroleum
# Well 	 (WELL): 		 15/9-F-1 B
# Field 	 (FLD): 		 VOLVE
# Location 	 (LOC): 		 Maersk Inspirer
# Province 	 (PROV):
# County 	 (CNTY):
# State 	 (STATE):
# Country 	 (CTRY):
# Log Date 	 (DATE):
# Service Company 	 (SRVC):
# Unique Well Identifier 	 (UWI): 		 1B
# API Number 	 (API):
# Latitude 	 (LATI): 		 058 26' 29.907" N    DMS
# Longtitude 	 (LONG): 		 001 53' 14.708" E    DMS
# Permanent Datum 	 (PD): 		 MSL
# Elev. Log Zero 	 (ELZ): 		 0.0

# %% [markdown]
# getting value of 'well'

# %%
las.well.WELL.value
# Out:
# '15/9-F-1 B'

# %%
las.sections['Curves'][:5]
# Out:
# [CurveItem(mnemonic="DEPTH", unit="M", value="00 001 00 00", descr="0  Depth", original_mnemonic="DEPTH", data.shape=(33191,)),
#  CurveItem(mnemonic="ABDCQF01", unit="g/cm3", value="00 000 00 00:   1  ABDCQF01:COMPOSITE:rC:NONE", descr="v1", original_mnemonic="ABDCQF01", data.shape=(33191,)),
#  CurveItem(mnemonic="ABDCQF02", unit="g/cm3", value="00 000 00 00:   2  ABDCQF02:COMPOSITE:rC:NONE", descr="v1", original_mnemonic="ABDCQF02", data.shape=(33191,)),
#  CurveItem(mnemonic="ABDCQF03", unit="g/cm3", value="00 000 00 00:   3  ABDCQF03:COMPOSITE:rC:NONE", descr="v1", original_mnemonic="ABDCQF03", data.shape=(33191,)),
#  CurveItem(mnemonic="ABDCQF04", unit="g/cm3", value="00 000 00 00:   4  ABDCQF04:COMPOSITE:rC:NONE", descr="v1", original_mnemonic="ABDCQF04", data.shape=(33191,))]

# %%
for curve in las.curves:
    print(curve.mnemonic)
# Out:
# DEPTH
# ABDCQF01
# ABDCQF02
# ABDCQF03
# ABDCQF04
# BS
# CALI
# DRHO
# DT
# DTS
# GR
# NBGRCFM
# NPHI
# PEF
# RACEHM
# RACELM
# RD
# RHOB
# RM
# ROP
# RPCEHM
# RPCELM
# RT

# %%
las.keys()
# Out:
# ['DEPTH',
#  'ABDCQF01',
#  'ABDCQF02',
#  'ABDCQF03',
#  'ABDCQF04',
#  'BS',
#  'CALI',
#  'DRHO',
#  'DT',
#  'DTS',
#  'GR',
#  'NBGRCFM',
#  'NPHI',
#  'PEF',
#  'RACEHM',
#  'RACELM',
#  'RD',
#  'RHOB',
#  'RM',
#  'ROP',
#  'RPCEHM',
#  'RPCELM',
#  'RT']

# %%
well = las.df()

# %%
well.head()
# Out:
#        ABDCQF01  ABDCQF02  ABDCQF03  ABDCQF04    BS  CALI  DRHO  DT  DTS  GR  \
# DEPTH
# 145.9       NaN       NaN       NaN       NaN  36.0   NaN   NaN NaN  NaN NaN
# 146.0       NaN       NaN       NaN       NaN  36.0   NaN   NaN NaN  NaN NaN
# 146.1       NaN       NaN       NaN       NaN  36.0   NaN   NaN NaN  NaN NaN
# 146.2       NaN       NaN       NaN       NaN  36.0   NaN   NaN NaN  NaN NaN
# 146.3       NaN       NaN       NaN       NaN  36.0   NaN   NaN NaN  NaN NaN
#
#        ...  PEF  RACEHM  RACELM  RD  RHOB  RM  ROP  RPCEHM  RPCELM  RT
# DEPTH  ...
# 145.9  ...  NaN     NaN     NaN NaN   NaN NaN  NaN     NaN     NaN NaN
# 146.0  ...  NaN     NaN     NaN NaN   NaN NaN  NaN     NaN     NaN NaN
# 146.1  ...  NaN     NaN     NaN NaN   NaN NaN  NaN     NaN     NaN NaN
# 146.2  ...  NaN     NaN     NaN NaN   NaN NaN  NaN     NaN     NaN NaN
# 146.3  ...  NaN     NaN     NaN NaN   NaN NaN  NaN     NaN     NaN NaN
#
# [5 rows x 22 columns]

# %%
well.describe()
# Out:
#           ABDCQF01     ABDCQF02     ABDCQF03     ABDCQF04            BS  \
# count  3226.000000  3226.000000  3226.000000  3226.000000  33191.000000
# mean      2.449846     2.447409     2.447272     2.449575     19.043252
# std       0.131558     0.130183     0.131161     0.132434      6.613720
# min       2.104600     2.118200     2.090200     2.124700      8.500000
# 25%       2.366375     2.359250     2.361750     2.360050     12.250000
# 50%       2.479150     2.478850     2.478250     2.479650     17.500000
# 75%       2.527275     2.526050     2.525200     2.526225     26.000000
# max       3.057700     3.052100     3.050500     3.086600     36.000000
#
#               CALI         DRHO           DT          DTS            GR  ...  \
# count  3519.000000  3526.000000  4262.000000  3809.000000  32498.000000  ...
# mean      8.677213     0.053590    80.380006   138.251061     56.864115  ...
# std       0.083978     0.023488    14.698333    19.335463     35.935409  ...
# ...

# %%
# well.columns

for i in well.columns:
    print(i)
# Out:
# ABDCQF01
# ABDCQF02
# ABDCQF03
# ABDCQF04
# BS
# CALI
# DRHO
# DT
# DTS
# GR
# NBGRCFM
# NPHI
# PEF
# RACEHM
# RACELM
# RD
# RHOB
# RM
# ROP
# RPCEHM
# RPCELM
# RT

# %%
well.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 33191 entries, 145.9 to 3464.9
# Data columns (total 22 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ABDCQF01  3226 non-null   float64
#  1   ABDCQF02  3226 non-null   float64
#  2   ABDCQF03  3226 non-null   float64
#  3   ABDCQF04  3226 non-null   float64
#  4   BS        33191 non-null  float64
#  5   CALI      3519 non-null   float64
#  6   DRHO      3526 non-null   float64
#  7   DT        4262 non-null   float64
#  8   DTS       3809 non-null   float64
#  9   GR        32498 non-null  float64
#  10  NBGRCFM   13187 non-null  float64
#  11  NPHI      3413 non-null   float64
#  12  PEF       3441 non-null   float64
#  13  RACEHM    8538 non-null   float64
#  14  RACELM    8538 non-null   float64
#  15  RD        31910 non-null  float64
#  16  RHOB      3441 non-null   float64
#  17  RM        31910 non-null  float64
#  18  ROP       32384 non-null  float64
# ...

# %%
# well.plot()
import os
 
dir = 'C:\Jimmy\Codeholic\ongc-wire\science\LAS\images'
for f in os.listdir(dir):
    os.remove(os.path.join(dir, f))

for i in well.columns:
    well.plot(y=i)
    
    plt.savefig(f"C:\Jimmy\Codeholic\ongc-wire\science\LAS\images\{i}.png")

# %%
well.plot(y='GR')
# Out:
# <AxesSubplot:xlabel='DEPTH'>

# %%
well.plot(y='ROP')
# Out:
# <AxesSubplot:xlabel='DEPTH'>

# %%
well.plot(y='ABDCQF01')
# Out:
# <AxesSubplot:xlabel='DEPTH'>

# %%
well.plot(y='ABDCQF02')
# Out:
# <AxesSubplot:xlabel='DEPTH'>

# %%
well.plot(y='ABDCQF03')
# Out:
# <AxesSubplot:xlabel='DEPTH'>

# %%
well.plot(y='ABDCQF04')
# Out:
# <AxesSubplot:xlabel='DEPTH'>

# %%
well.plot(y='BS')
# Out:
# <AxesSubplot:xlabel='DEPTH'>

# %%
well.plot(y='CALI')
# Out:
# <AxesSubplot:xlabel='DEPTH'>

# %%
well.plot(y='DRHO')
# Out:
# <AxesSubplot:xlabel='DEPTH'>

# %%
well.plot(y='DT')
# Out:
# <AxesSubplot:xlabel='DEPTH'>

# %%
well.plot(y='DTS')
# Out:
# <AxesSubplot:xlabel='DEPTH'>

# %%
well.plot(y='NBGRCFM')
# Out:
# <AxesSubplot:xlabel='DEPTH'>

# %%
well.plot(y='NPHI')
# Out:
# <AxesSubplot:xlabel='DEPTH'>

# %%
well.plot(y='PEF')
# Out:
# <AxesSubplot:xlabel='DEPTH'>

# %%
well.plot(y='RACEHM')
# Out:
# <AxesSubplot:xlabel='DEPTH'>

# %%
well.plot(y='RACELM')
# Out:
# <AxesSubplot:xlabel='DEPTH'>

# %%
well.plot(y='RD')
# Out:
# <AxesSubplot:xlabel='DEPTH'>

# %%
well.plot(y='RHOB')
# Out:
# <AxesSubplot:xlabel='DEPTH'>

# %%
well.plot(y='RM')
# Out:
# <AxesSubplot:xlabel='DEPTH'>

# %%
well.plot(y='RPCEHM')
# Out:
# <AxesSubplot:xlabel='DEPTH'>

# %%
well.plot(y='RPCELM')
# Out:
# <AxesSubplot:xlabel='DEPTH'>

# %%
well.plot(y='RT')
# Out:
# <AxesSubplot:xlabel='DEPTH'>
